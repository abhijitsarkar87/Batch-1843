# %% [markdown]
# # SEABORN visualization Library

# %% [markdown]
# Seaborn is a Python Data visualization library bassed on a matplotlib.It provides a high level interface for drawing attractive and informative statistical graphics.
#
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce imformative plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# git hub---> dataset1----->iris.csv

# %%
dsiris=pd.read_csv(r"C:\Users\jitsa\Documents\iris.csv")

# %%
print(dsiris)
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# checking top 5 
dsiris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.set(style="whitegrid") #seaborn.set background as whitegrid
ax=sns.stripplot(x='class',y='sepal length',data=dsiris) #seaborn.stripplot(x|y axis class name, x|y graph name,data=(data source)
plt.title('Graph')
plt.show()

# %%
# geting new map(swarmplot- swarmm of bees like structure)

ax=sns.swarmplot(x='class',y='sepal length',data=dsiris)
plt.title('Graph')
plt.show()

# %%
ax=sns.swarmplot(x='sepal length',y='class',data=dsiris)
plt.title('Graph')
plt.show()

# %%
dsiris['class'].value_counts() # checking total iris flower sample
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
# checking count on map by using seaborn library all 50 rows

sns.countplot(dsiris['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.get_dataset_names() # checking datasets available in seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#loading DataSet.(ds is dataset)
titanicds=sns.load_dataset("titanic")
print(titanicds)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# checking columns 

titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# checking classes

titanicds['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
# checking the total number of persons in 3 classes

titanicds['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %% [markdown]
# CATEGORY PLOT

# %%
# checking in seaborn library total number of people in 3 classes in map

sns.countplot(titanicds['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
#sns.catplot?

# %%
# SET UP A CATEGORY PLOT

g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds, kind='bar')
#show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
 # checking datasets available in seaborn(default ds)
    
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# sns.load_dataset("tips")

# %% [markdown]
# Distribution plot
#
# displot    : Figure-level interface to distribution plot function
# histplot   : Plot a histogram of binned counts with optional normalisation or smoothing.
# jointplot  : Draw a bivariate plot with universal distribution.
# violinplot : Draw an enhenced boxplot using kernal density estimation.
# rugplot    : Plot marginal distributions by drawing tricks along the x and y axis

# %%
import seaborn as sns

# %%
#load the data

tipsds =sns.load_dataset('tips')

# %%
print(tipsds.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#creating violinplot
sns.violinplot(x="total_bill",data=tipsds)
plt.show()

# %%
#sns.histplot?

# %%
sns.histplot(data=tipsds,x="total_bill",bins=20)

# it would give us data that maximum 28,32,more the 35 paid bill more than 35
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tipsds["tip"],bins=10)

# this shows the density of bill
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tipsds["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tipsds["total_bill"],bins=100)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tipsds["total_bill"],bins=50,kde=False)

# KDE is kernel Density Eleminator
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot?

# %%
import seaborn as sns

# %%
sns.kdeplot(tipsds["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot?
