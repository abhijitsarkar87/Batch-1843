# %%
import pandas as pd

# %%
data={'day':[1,2,3,4,5,6],'Visitors':[200,100,300,230,450,400],'Bounce_Rate':[20,10,30,23,45,40]}

p=pd.DataFrame(data)

# %%
p
# Out:
#    day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           10
# 2    3       300           30
# 3    4       230           23
# 4    5       450           45
# 5    6       400           40

# %%
p.head()
# Out:
#    day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           10
# 2    3       300           30
# 3    4       230           23
# 4    5       450           45

# %%
p.tail()
# Out:
#    day  Visitors  Bounce_Rate
# 1    2       100           10
# 2    3       300           30
# 3    4       230           23
# 4    5       450           45
# 5    6       400           40

# %%
p.tail(2)
# Out:
#    day  Visitors  Bounce_Rate
# 4    5       450           45
# 5    6       400           40

# %%
p.tail(3)
# Out:
#    day  Visitors  Bounce_Rate
# 3    4       230           23
# 4    5       450           45
# 5    6       400           40

# %%
p.head(3)
# Out:
#    day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           10
# 2    3       300           30

# %%
p.sample()
# Out:
#    day  Visitors  Bounce_Rate
# 0    1       200           20

# %%
p.sample(2)
# Out:
#    day  Visitors  Bounce_Rate
# 3    4       230           23
# 2    3       300           30

# %% [markdown]
# # READING CSV WITH PANDAS

# %%
import pandas as pd

# %%
df=pd.read_csv("hrdata.csv") # loading hrdata.csv

# %%
df
# Out:
#              Name  HireDate   Salary  SickDaysremaining
# 0  Graham Chapman  03/15/14  50000.0                 10
# 1     John Cleese  06/01/15  65000.0                  8
# 2       Eric Idle  05/12/14  45000.0                 10
# 3     Terry Jones  11/01/13  70000.0                  3
# 4   Terry Gilliam  08/12/14  48000.0                  7
# 5   Michael Palin  05/23/13  66000.0                  8

# %%
df.head()
# Out:
#              Name  HireDate   Salary  SickDaysremaining
# 0  Graham Chapman  03/15/14  50000.0                 10
# 1     John Cleese  06/01/15  65000.0                  8
# 2       Eric Idle  05/12/14  45000.0                 10
# 3     Terry Jones  11/01/13  70000.0                  3
# 4   Terry Gilliam  08/12/14  48000.0                  7

# %%
type(df['HireDate'][0])
# Out:
# str

# %%
print(type(df['HireDate'][0]))  # checking class
# Out:
# <class 'str'>

# %%
# parse_date....will change the date type index will change the index value

df=pd.read_csv('hrdata.csv',index_col='Name',parse_dates=['HireDate'])
print(df)

#inbuilt parameter
# Out:
#                  HireDate   Salary  SickDaysremaining
# Name
# Graham Chapman 2014-03-15  50000.0                 10
# John Cleese    2015-06-01  65000.0                  8
# Eric Idle      2014-05-12  45000.0                 10
# Terry Jones    2013-11-01  70000.0                  3
# Terry Gilliam  2014-08-12  48000.0                  7
# Michael Palin  2013-05-23  66000.0                  8

# %%
type(df['HireDate'][0]) #HireDate changed to timestamp showing datetype
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(df['HireDate'][2]) # type datetype
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
pandas.read_csv? #nothing found
# Out:
# Object `pandas.read_csv` not found.

# %%
# Explictly pass header=0 to be able to replace exixsting names at time of loading.

df=pd.read_csv('hrdata.csv',
              index_col='Names',
              parse_dates=['Hire_Date'],
              header=0,
              names=['Names','Hire_Date','Salary','Sick_Days'])
print(df)
# Out:
#                 Hire_Date   Salary  Sick_Days
# Names
# Graham Chapman 2014-03-15  50000.0         10
# John Cleese    2015-06-01  65000.0          8
# Eric Idle      2014-05-12  45000.0         10
# Terry Jones    2013-11-01  70000.0          3
# Terry Gilliam  2014-08-12  48000.0          7
# Michael Palin  2013-05-23  66000.0          8

# %%
# saving file to csv.

df1=df.to_csv("modified_hrdata.csv")

# %%
dfn=pd.read_csv("modified_hrdata.csv")

# %%
dfn
# Out:
#             Names   Hire_Date   Salary  Sick_Days
# 0  Graham Chapman  2014-03-15  50000.0         10
# 1     John Cleese  2015-06-01  65000.0          8
# 2       Eric Idle  2014-05-12  45000.0         10
# 3     Terry Jones  2013-11-01  70000.0          3
# 4   Terry Gilliam  2014-08-12  48000.0          7
# 5   Michael Palin  2013-05-23  66000.0          8

# %%
type(dfn['Hire_Date'][0])
# Out:
# str

# %%
dfn['Salary'].plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
dfn['Salary'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
dfn.max()
# Out:
# Names        Terry Jones
# Hire_Date     2015-06-01
# Salary           70000.0
# Sick_Days             10
# dtype: object

# %%
dfn.min()
# Out:
# Names         Eric Idle
# Hire_Date    2013-05-23
# Salary          45000.0
# Sick_Days             3
# dtype: object

# %%
dfn['Sick_Days'].min()
# Out:
# 3

# %%
df['Salary'].max()
# Out:
# 70000.0

# %%
pandas.read_csv?
# Out:
# Object `pandas.read_csv` not found.

# %%
import pandas as pd

# %% [markdown]
# ### Tab Separation

# %%
df=pd.read_csv('agedata.csv',sep='\t')

# %%
df
# Out:
#    Sno     Name  Age
# 0    1     John    5
# 1    2     Jack   10
# 2    3     Lisa    8
# 3    4    Sweta   11
# 4    5     Bret   14
# 5    6  Nikolus   10

# %%
df=pd.read_csv('agedata.csv',
               sep='\t',
              index_col='S.No',
              header=0,
              names=['S.No','Name','Age'])
print(df)
# Out:
#          Name  Age
# S.No
# 1        John    5
# 2        Jack   10
# 3        Lisa    8
# 4       Sweta   11
# 5        Bret   14
# 6     Nikolus   10

# %%
df1=df.to_csv('New_agedata.csv')

# %% [markdown]
# ### Reading Excel File:

# %%
# df=pd.read_execl('file name')----> to read data
# df.to_excel('file_name')---> to save xlx

# %% [markdown]
# ### Reading HTML file:

# %%
df3=pd.read_html("emp.html")

# %%
df3
# Out:
# [   Unnamed: 0_level_0               Name                Age  \
#                    SNo Unnamed: 1_level_1 Unnamed: 2_level_1
#  0                   1                Tom               28.0
#  1                   2                Lee               31.0
#  2                   3               Dave               34.0
#  3                   4               Anik               26.0
#  4                   5              kamal               30.0
#  5                   6               Geet               22.0
#  6                   7             Steven               43.0
#  7                   8                Ram               38.0
#  8                   9               hari               50.0
#  9                  11               yami               27.0
#  10                 12               Anik               26.0
#  11                 13              kamal               30.0
#  12                 14               Geet               22.0
# ...

# %% [markdown]
# url:"https:_______________________________________"
#
# df3=pd.read_html(url)
#
#
# df2=df3.to_html("file name")

# %% [markdown]
# ### Web API-Application Programming Interface

# %% [markdown]
# Making API requests in python

# %%
#!pip install requests

# %%
import requests

# %%
response=requests.get("https://en.wikipedia.org/wiki/Data_science")

# %%
response.status_code # access granted
# Out:
# 200

# %%
response=requests.get("https://en.wikipedia.org/wiki/Data_science_does_not_exist")

# %%
response.status_code # cant acess!
# Out:
# 404

# %%
import pandas as pd

# %%
df=pd.read_csv("empl.csv")

# %%
df.head()
# Out:
#    SNo   Name   Age      City  Country   Salary
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
url="https://github.com/dsrscientist/dataset1/blob/master/empl.csv"
df=pd.read_html(url)

# %%
df
# Out:
# [    Unnamed: 0  SNo    Name   Age       City  Country   Salary
#  0          NaN    1     Tom  28.0    Toronto   Canada  20000.0
#  1          NaN    2     Lee  31.0    Edmonto   Canada   3900.0
#  2          NaN    3    Dave  34.0    Toronto   Canada   8000.0
#  3          NaN    4    Anik  26.0   HongKong     Asia  66672.0
#  4          NaN    5   kamal  30.0        NaN  America      NaN
#  5          NaN    6    Geet   NaN   HongKong     Asia  30007.0
#  6          NaN    7  Steven  43.0    BayArea  America   8300.0
#  7          NaN    8     Ram  38.0  Hyderabad     Asia  54666.0
#  8          NaN    9    hari  50.0    newyork  America  67666.0
#  9          NaN   11    yami   NaN    newyork  America   8888.0
#  10         NaN   12    Anik  26.0   HongKong     Asia  66672.0
#  11         NaN   13   kamal  30.0        NaN  America  34344.0
#  12         NaN   14    Geet  22.0   HongKong     Asia  30007.0
#  13         NaN   15  Steven  43.0        NaN  America   8300.0
# ...

# %%
df=pd.read_csv("empl.csv",
               sep=",",
              index_col="SNo")
print(df)
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df['Salary'].max()
# Out:
# 67666.0

# %%
df['Salary'].min()
# Out:
# 3900.0

# %%
df['Salary'].plot.bar()
# Out:
# <AxesSubplot:xlabel='SNo'>

# %%
# Transfering data from one data frame to another DataFrame

# %%
df1=pd.DataFrame(data=df)

# %%
df1
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1.iloc[:,0:2]
# Out:
#        Name   Age
# SNo
# 1       Tom  28.0
# 2       Lee  31.0
# 3      Dave  34.0
# 4      Anik  26.0
# 5     kamal  30.0
# 6      Geet   NaN
# 7    Steven  43.0
# 8       Ram  38.0
# 9      hari  50.0
# 11     yami   NaN
# 12     Anik  26.0
# 13    kamal  30.0
# 14     Geet  22.0
# 15   Steven  43.0
# 16      Ram  38.0
# 17     hari   NaN
# 18     yami  27.0
# 19      Lee  31.0
# 20   Andrew  34.0
# 21    soham  32.0
# 22     Grig  26.0
# 23    Kiara  27.0

# %%
df1.iloc[:,-1]
# Out:
# SNo
# 1     20000.0
# 2      3900.0
# 3      8000.0
# 4     66672.0
# 5         NaN
# 6     30007.0
# 7      8300.0
# 8     54666.0
# 9     67666.0
# 11     8888.0
# 12    66672.0
# 13    34344.0
# 14    30007.0
# 15     8300.0
# 16    54666.0
# 17    67666.0
# 18     8888.0
# 19        NaN
# 20    34432.0
# 21    34534.0
# 22    33451.0
# 23        NaN
# Name: Salary, dtype: float64

# %%
# checking particular col.

df1.loc[:,['Name','Salary']]
# Out:
#        Name   Salary
# SNo
# 1       Tom  20000.0
# 2       Lee   3900.0
# 3      Dave   8000.0
# 4      Anik  66672.0
# 5     kamal      NaN
# 6      Geet  30007.0
# 7    Steven   8300.0
# 8       Ram  54666.0
# 9      hari  67666.0
# 11     yami   8888.0
# 12     Anik  66672.0
# 13    kamal  34344.0
# 14     Geet  30007.0
# 15   Steven   8300.0
# 16      Ram  54666.0
# 17     hari  67666.0
# 18     yami   8888.0
# 19      Lee      NaN
# 20   Andrew  34432.0
# 21    soham  34534.0
# 22     Grig  33451.0
# 23    Kiara      NaN

# %%
df1.head()
# Out:
#       Name   Age      City  Country   Salary
# SNo
# 1      Tom  28.0   Toronto   Canada  20000.0
# 2      Lee  31.0   Edmonto   Canada   3900.0
# 3     Dave  34.0   Toronto   Canada   8000.0
# 4     Anik  26.0  HongKong     Asia  66672.0
# 5    kamal  30.0       NaN  America      NaN

# %%
df1.loc[1:8,['Name','Age','Salary']]
# Out:
#        Name   Age   Salary
# SNo
# 1       Tom  28.0  20000.0
# 2       Lee  31.0   3900.0
# 3      Dave  34.0   8000.0
# 4      Anik  26.0  66672.0
# 5     kamal  30.0      NaN
# 6      Geet   NaN  30007.0
# 7    Steven  43.0   8300.0
# 8       Ram  38.0  54666.0

# %%
df.count() # showing entire count
# Out:
# Name       22
# Age        19
# City       19
# Country    22
# Salary     19
# dtype: int64

# %%
df['Name'].count() # total names count
# Out:
# 22

# %%
df['Name'].unique() #total unique names are here
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
df['Name'].nunique() # total number of unique names
# Out:
# 14

# %%
df['City'].unique()
# Out:
# array(['Toronto', 'Edmonto', 'HongKong', nan, 'BayArea', 'Hyderabad',
#        'newyork', 'Congo', 'Angola', 'Finland', 'London'], dtype=object)

# %%
df['City'].nunique()
# Out:
# 10

# %%
print(df1['Name'].describe()) # will give complete name description
# Out:
# count      22
# unique     14
# top       Lee
# freq        2
# Name: Name, dtype: object

# %%
print(df1['City'].describe()) # will give complete description
# Out:
# count           19
# unique          10
# top       HongKong
# freq             4
# Name: City, dtype: object

# %%
df1.describe() # complete detailed statical description of all intger data
# Out:
#              Age        Salary
# count  19.000000     19.000000
# mean   32.421053  33739.947368
# std     7.174924  23151.188084
# min    22.000000   3900.000000
# 25%    27.000000   8888.000000
# 50%    31.000000  33451.000000
# 75%    36.000000  54666.000000
# max    50.000000  67666.000000

# %%
df1.describe(include='all') # all int and str data will be given
# Out:
#        Name        Age      City  Country        Salary
# count    22  19.000000        19       22     19.000000
# unique   14        NaN        10        5           NaN
# top     Lee        NaN  HongKong  America           NaN
# freq      2        NaN         4        8           NaN
# mean    NaN  32.421053       NaN      NaN  33739.947368
# std     NaN   7.174924       NaN      NaN  23151.188084
# min     NaN  22.000000       NaN      NaN   3900.000000
# 25%     NaN  27.000000       NaN      NaN   8888.000000
# 50%     NaN  31.000000       NaN      NaN  33451.000000
# 75%     NaN  36.000000       NaN      NaN  54666.000000
# max     NaN  50.000000       NaN      NaN  67666.000000

# %% [markdown]
# ----------------------------------------------------------

# %% [markdown]
# ### DROPPING OF ROWS AND COLUMN IN PANDAS

# %%
df1()
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Salary'], dtype='object')

# %%
df2=df1.drop([14,15,16,17],axis=0) # axis 0 means rows(14,15,16,17 is dropped)

df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df1 # checking old csv
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1.drop([1,2,3],inplace=True,axis=0)

# %%
df1
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df3=df1.drop('Name',axis=1) # drop done with column 'Name'

# %%
df3 # name dropped.
# Out:
#       Age       City  Country   Salary
# SNo
# 4    26.0   HongKong     Asia  66672.0
# 5    30.0        NaN  America      NaN
# 6     NaN   HongKong     Asia  30007.0
# 7    43.0    BayArea  America   8300.0
# 8    38.0  Hyderabad     Asia  54666.0
# 9    50.0    newyork  America  67666.0
# 11    NaN    newyork  America   8888.0
# 12   26.0   HongKong     Asia  66672.0
# 13   30.0        NaN  America  34344.0
# 14   22.0   HongKong     Asia  30007.0
# 15   43.0        NaN  America   8300.0
# 16   38.0  Hyderabad     Asia  54666.0
# 17    NaN    newyork  America  67666.0
# 18   27.0    newyork  America   8888.0
# 19   31.0    Edmonto   Canada      NaN
# 20   34.0      Congo   Africa  34432.0
# 21   32.0     Angola   Africa  34534.0
# 22   26.0    Finland   Europe  33451.0
# 23   27.0     London   Europe      NaN

# %%
df3.drop(['Age','Salary'],axis=1,inplace=True)

# %%
df3
# Out:
#           City  Country
# SNo
# 4     HongKong     Asia
# 5          NaN  America
# 6     HongKong     Asia
# 7      BayArea  America
# 8    Hyderabad     Asia
# 9      newyork  America
# 11     newyork  America
# 12    HongKong     Asia
# 13         NaN  America
# 14    HongKong     Asia
# 15         NaN  America
# 16   Hyderabad     Asia
# 17     newyork  America
# 18     newyork  America
# 19     Edmonto   Canada
# 20       Congo   Africa
# 21      Angola   Africa
# 22     Finland   Europe
# 23      London   Europe

# %%
df3.drop([12,13,14,15],axis=0,inplace=True)

# %%
df3
# Out:
#           City  Country
# SNo
# 4     HongKong     Asia
# 5          NaN  America
# 6     HongKong     Asia
# 7      BayArea  America
# 8    Hyderabad     Asia
# 9      newyork  America
# 11     newyork  America
# 16   Hyderabad     Asia
# 17     newyork  America
# 18     newyork  America
# 19     Edmonto   Canada
# 20       Congo   Africa
# 21      Angola   Africa
# 22     Finland   Europe
# 23      London   Europe

# %% [markdown]
# ### DATA Munging:
#
# ###### changing the files extension or type from one to another ex: csv to html

# %%
df3.to_html("Residuel.html")
