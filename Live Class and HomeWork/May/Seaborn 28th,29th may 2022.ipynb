# %% [markdown]
# # SEABORN visualization Library

# %% [raw]
# Seaborn is a Python Data visualization library bassed on a matplotlib.It provides a high level interface for drawing attractive and informative statistical graphics.
#
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce imformative plots.

# %% [markdown]
# Category plots:
#
#     1.Stripplot
#     2.Swarmplot
#     3.Countplot
#     4.Catplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## IRIS FLOWER DATASET:

# %%
ds=pd.read_csv("iris.csv")

# %%
ds
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# one numerical and one class(By category)

sns.set(style="whitegrid") #background style
ax=sns.stripplot(x='class',y='sepal length',data=ds)
plt.title("Iris category Plot")
plt.show()

# %%
sns.set(style="whitegrid") #background
# x is class and y is sepel width.
ax=sns.stripplot(x='class',y='sepal width',data=ds)
plt.title("Iris category Plot by width")
plt.show()

# %%
sns.swarmplot(x='class',y='sepal length',data=ds)
plt.title("Category Plot")
plt.show()

# %%
sns.swarmplot(x='petal length',y='class',data=ds)
plt.title("Category PLot ")
plt.show()
# Out:
# C:\Users\jitsa\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#counting by class:
ds['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
#by seaborn we can check count by graph

sns.countplot(ds['class'])
# Out:
# C:\Users\jitsa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# total data set here in seaborn

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# loading data set.

titanicds=sns.load_dataset("titanic")

# %%
titanicds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanicds['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
titanicds['class'].value_counts() # total number of person in titanic
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(titanicds['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.catplot?

# %%
# seting up a category plot

g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='bar')
plt.show()

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Distribution Plot:
#
# >displot: Figure-level interface to distribution plot functions.
#
# >histplot   : Plot a histogram of binned counts with optional normalization or smoothing.
#
# >jointplot  : Draw a bivariate plot with univariate marginal distributions.
#
# >violinplot : Draw an enhanced boxplot using kernal density estimation.
#
# >rugplot: Plot marginal distributions by drawing ticks along the x and y axes.

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='total_bill',data=tips)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sns.histplot?

# %%
sns.histplot(data=tips,x='total_bill',bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips['tip'],bins=10)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
#sns.histplot?

# %%
sns.histplot(data=tips,x="total_bill",bins=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips,x="total_bill",bins=100)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
# for distplot. KDE=kernal density estimation.

sns.displot(tips['total_bill'],bins=50,kde=True)

# %%
sns.displot(tips['total_bill'],bins=50,kde=False) #no KDE

# %%
#sns.kdeplot?

# %%
sns.kdeplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# #### COMPOSITE VIEWS ONTO MULTIVARIATE DATASETS.

# %%
sns.jointplot(data=tips,x='total_bill',y='tip') 

# bill increases then tips also gets increased, 02-04 tips are max

# %%
sns.rugplot(data=tips,x='total_bill',y='tip') 
# rugplot shows max amount tips paid is between 2 to 4
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Categorical Distribution Plot

# %% [markdown]
# The first is the familier boxplot().This kind of plot shows the three quartile values of the distribution along with extreme values. The "whiskers" extend to points that lie within 1.5 IQrs of the lower and upper quartil, and the observations that fall outside the range are displayed independently.This means that each value in the boxplot corresponds to an actual observation in the data.

# %%
sns.boxplot?

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=tips, palette="coolwarm")
# kind=? parameter is not given in this parameter
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [raw]
# #Observation
#
# # Thur smokers spent min 11$ to max 29$ and non-smoker spent 7$ to 30$
# # Fri smokers spent min 5$ to max 29$ and non-smoker spent 14$ to 23$ resp.
# # Smokers have paid max bill then non-smokers,
# # Max sale is on sunday and saturday.
#
# """

# %%
sns.pairplot(tips)

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=tips)

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=tips)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpgds=sns.load_dataset('mpg')

# %%
mpgds.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [raw]
# #Note:
#
# """
# Categorial plot:- IN X or Y, X is the class(one is str),y is the  number(one is real,int)
# >strip plot
# >swarm plot
# >cat plot
#
#
# Numerical plot:- Both x, y must be int or numerical
# Numerical plots are:
#
# >scatter plot
# >rel plot
# >line plot

# %%
# here x and y values must be int or numerical.

sns.scatterplot(data=mpgds,x='mpg',y='weight')

# weight of the car,affects the mileage of the car
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %%
sns.scatterplot(data=mpgds,x='horsepower',y='mpg')

# increase in horsepower,is affecting the mileage of the car.
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
#sns.lineplot?

# %%
sns.lineplot(x="weight",y="mpg",data=mpgds,)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
#sns.relplot?

# %%
sns.relplot(x="weight",y="mpg",data=mpgds)

# %% [markdown]
# Regression Plot:

# %%
sns.regplot(x="weight",y="mpg",data=mpgds)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.boxplot(x='weight',data=mpgds)
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
sns.boxplot(x='displacement',data=mpgds)
# Out:
# <AxesSubplot:xlabel='displacement'>

# %%
sns.rugplot(data=mpgds,x='weight',y='mpg')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg')

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='kde')

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='hex')

# %%
sns.stripplot(data=mpgds,x='origin',y='mpg')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
#sns.swarmplot?

# %%
sns.swarmplot(data=mpgds, x='origin', y='mpg')
# Out:
# C:\Users\jitsa\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#sns.catplot?

# %%
sns.catplot(data=mpgds,x='origin',y='mpg',kind='box')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxids=sns.load_dataset('taxis')

# %%
taxids
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
#fair along with distance

sns.scatterplot(x='fare',y='distance',data=taxids)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='distance'>

# %%
taxids['color'].value_counts()
# Out:
# yellow    5451
# green      982
# Name: color, dtype: int64

# %%
sns.countplot(x='color',data=taxids)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
taxids['payment'].value_counts()
# Out:
# credit card    4577
# cash           1812
# Name: payment, dtype: int64

# %%
sns.countplot(x='payment',data=taxids)
# Out:
# <AxesSubplot:xlabel='payment', ylabel='count'>

# %%
sns.stripplot(x='color',y='fare',data=taxids)
# Out:
# <AxesSubplot:xlabel='color', ylabel='fare'>

# %%
sns.boxplot(x='color',y='fare',hue='payment',data=taxids)
# Out:
# <AxesSubplot:xlabel='color', ylabel='fare'>

# %% [raw]
# #observation.
# credit cards payments are more on compersion to cash payment.

# %%
#sns.lmplot?

# %%
sns.lmplot(x='distance',y='fare',data=taxids)

# %%
sns.lmplot(x='distance',y='fare',data=taxids,hue='payment')

# %%
sns.lmplot(x='distance',y='fare',data=taxids,hue='payment',col='color')

# %%
# 70 percent in credit card,30 percent cash
# cash money is overpaid as conparison to card.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxids=sns.load_dataset('taxis')

# %%
sns.lmplot('distance','fare',data=taxids,hue='payment',col='color')

# %% [markdown]
# ## Heatmap:

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import seaborn as sns
flights=sns.load_dataset("flights")

# pivot will take 3 parameter(month,year, passenger boarded)

flights=flights.pivot("month","year","passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
ax=sns.heatmap(flights) 
# lighter side is showing positive side, dark side is showing negativity side of datas

# %% [raw]
# # Observation.
#
# >loads are quite higher in jun,july,aug with comparison to other months.
#
# >1960 is showing a bright future for air transport as loads are increasing.
#
# > highest population in jun,july,aug

# %% [markdown]
#                         ## Done with Seaborn.
